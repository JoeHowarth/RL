# %%
import json
import numpy as np
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Dense, Dropout, Activation, Flatten
# Out:
# Using TensorFlow backend.

# %%
# parameters
epsilon = .1  # exploration
num_actions = 3  # [move_left, stay, move_right]
epoch = 10000
max_memory = 500
hidden_size = 64
batch_size = 50
grid_size = 16

model = Sequential()
model.add(Conv2D(4, (3,3), activation='relu', strides=(2,2) , input_shape=(grid_size, grid_size, 1)))
# model.add(Conv2D(4, (5,5), activation='relu', input_shape=(grid_size, grid_size, 1)))
model.add(Conv2D(6, (3, 3), activation='relu'))
model.add(Conv2D(8, (3, 3), activation='relu'))
# model.add(Conv2D(1, (1,1), activation='relu'))
model.add(Flatten()) # converts to 1-D

model.add(Dense(hidden_size*2, activation='relu'))
model.add(Dense(hidden_size, activation='relu'))
# model.add(Dense(hidden_size, activation='relu'))
model.add(Dense(num_actions))
model.compile(sgd(lr=.2), "mse")

# If you want to continue training from a previous model, just uncomment the line bellow
# model.load_weights("model.h5")

# Define environment/game
env = Catch(grid_size)

# Initialize experience replay object
exp_replay = ExperienceReplay(max_memory=max_memory)

train(model)
# Out:
# wins in last 100: 1
# Epoch 000/999 | Loss 0.0443 | Win count 1
# Epoch 001/999 | Loss 0.2046 | Win count 1
# Epoch 002/999 | Loss 0.3107 | Win count 1
# Epoch 003/999 | Loss 0.3137 | Win count 2
# Epoch 004/999 | Loss 0.2429 | Win count 2
# Epoch 005/999 | Loss 0.3135 | Win count 2
# Epoch 006/999 | Loss 0.2909 | Win count 2
# Epoch 007/999 | Loss 0.3463 | Win count 2
# Epoch 008/999 | Loss 0.2780 | Win count 2
# Epoch 009/999 | Loss 0.2226 | Win count 3
# Epoch 010/999 | Loss 0.3053 | Win count 3
# Epoch 011/999 | Loss 0.2582 | Win count 3
# Epoch 012/999 | Loss 0.2730 | Win count 3
# Epoch 013/999 | Loss 0.3047 | Win count 3
# Epoch 014/999 | Loss 0.2359 | Win count 3
# Epoch 015/999 | Loss 0.3391 | Win count 3
# Epoch 016/999 | Loss 0.2920 | Win count 3
# Epoch 017/999 | Loss 0.2837 | Win count 3
# Epoch 018/999 | Loss 0.2586 | Win count 3
# Epoch 019/999 | Loss 0.3242 | Win count 3
# Epoch 020/999 | Loss 0.3016 | Win count 3
# Epoch 021/999 | Loss 0.2528 | Win count 3
# Epoch 022/999 | Loss 0.2739 | Win count 3
# Epoch 023/999 | Loss 0.2912 | Win count 3
# Epoch 024/999 | Loss 0.2893 | Win count 3
# Epoch 025/999 | Loss 0.1755 | Win count 3
# Epoch 026/999 | Loss 0.2803 | Win count 3
# Epoch 027/999 | Loss 0.2550 | Win count 3
# Epoch 028/999 | Loss 0.2398 | Win count 3
# Epoch 029/999 | Loss 0.1788 | Win count 3
# Epoch 030/999 | Loss 0.1945 | Win count 4
# Epoch 031/999 | Loss 0.2507 | Win count 4
# Epoch 032/999 | Loss 0.2638 | Win count 5
# Epoch 033/999 | Loss 0.2518 | Win count 5
# Epoch 034/999 | Loss 0.2014 | Win count 5
# Epoch 035/999 | Loss 0.2680 | Win count 5
# Epoch 036/999 | Loss 0.3017 | Win count 5
# Epoch 037/999 | Loss 0.2039 | Win count 6
# Epoch 038/999 | Loss 0.2528 | Win count 6
# Epoch 039/999 | Loss 0.2699 | Win count 6
# Epoch 040/999 | Loss 0.2097 | Win count 6
# Epoch 041/999 | Loss 0.1943 | Win count 6
# Epoch 042/999 | Loss 0.1908 | Win count 6
# Epoch 043/999 | Loss 0.1926 | Win count 6
# Epoch 044/999 | Loss 0.2229 | Win count 7
# Epoch 045/999 | Loss 0.1968 | Win count 7
# Epoch 046/999 | Loss 0.2498 | Win count 7
# Epoch 047/999 | Loss 0.2222 | Win count 7
# Epoch 048/999 | Loss 0.2424 | Win count 7
# Epoch 049/999 | Loss 0.1898 | Win count 7
# Epoch 050/999 | Loss 0.2378 | Win count 7
# Epoch 051/999 | Loss 0.2058 | Win count 8
# Epoch 052/999 | Loss 0.2026 | Win count 8
# Epoch 053/999 | Loss 0.2608 | Win count 9
# Epoch 054/999 | Loss 0.2352 | Win count 9
# Epoch 055/999 | Loss 0.2540 | Win count 9
# Epoch 056/999 | Loss 0.2249 | Win count 9
# Epoch 057/999 | Loss 0.3268 | Win count 9
# Epoch 058/999 | Loss 0.2377 | Win count 10
# Epoch 059/999 | Loss 0.2919 | Win count 10
# Epoch 060/999 | Loss 0.3895 | Win count 10
# Epoch 061/999 | Loss 0.2393 | Win count 10
# Epoch 062/999 | Loss 0.3320 | Win count 10
# Epoch 063/999 | Loss 0.3023 | Win count 10
# Epoch 064/999 | Loss 0.2419 | Win count 10
# Epoch 065/999 | Loss 0.2329 | Win count 10
# Epoch 066/999 | Loss 0.2276 | Win count 10
# Epoch 067/999 | Loss 0.2001 | Win count 10
# Epoch 068/999 | Loss 0.2440 | Win count 10
# Epoch 069/999 | Loss 0.2842 | Win count 11
# Epoch 070/999 | Loss 0.1930 | Win count 11
# Epoch 071/999 | Loss 0.2666 | Win count 11
# Epoch 072/999 | Loss 0.2779 | Win count 11
# Epoch 073/999 | Loss 0.2941 | Win count 11
# Epoch 074/999 | Loss 0.2182 | Win count 11
# Epoch 075/999 | Loss 0.2071 | Win count 12
# Epoch 076/999 | Loss 0.2608 | Win count 12
# Epoch 077/999 | Loss 0.2729 | Win count 12
# Epoch 078/999 | Loss 0.2425 | Win count 13
# Epoch 079/999 | Loss 0.2173 | Win count 13
# Epoch 080/999 | Loss 0.2376 | Win count 13
# Epoch 081/999 | Loss 0.2149 | Win count 13
# Epoch 082/999 | Loss 0.2571 | Win count 13
# Epoch 083/999 | Loss 0.2298 | Win count 14
# Epoch 084/999 | Loss 0.2582 | Win count 14
# Epoch 085/999 | Loss 0.3000 | Win count 14
# Epoch 086/999 | Loss 0.2005 | Win count 14
# Epoch 087/999 | Loss 0.2413 | Win count 14
# Epoch 088/999 | Loss 0.2629 | Win count 14
# Epoch 089/999 | Loss 0.2338 | Win count 14
# Epoch 090/999 | Loss 0.1907 | Win count 14
# Epoch 091/999 | Loss 0.2580 | Win count 14
# Epoch 092/999 | Loss 0.2359 | Win count 14
# Epoch 093/999 | Loss 0.2453 | Win count 14
# Epoch 094/999 | Loss 0.2105 | Win count 14
# Epoch 095/999 | Loss 0.2187 | Win count 15
# Epoch 096/999 | Loss 0.2486 | Win count 15
# Epoch 097/999 | Loss 0.2547 | Win count 15
# Epoch 098/999 | Loss 0.2866 | Win count 15
# Epoch 099/999 | Loss 0.2839 | Win count 15
# wins in last 100: 14
# Epoch 100/999 | Loss 0.2234 | Win count 15
# Epoch 101/999 | Loss 0.3142 | Win count 15
# Epoch 102/999 | Loss 0.2005 | Win count 15
# Epoch 103/999 | Loss 0.2660 | Win count 16
# Epoch 104/999 | Loss 0.2573 | Win count 16
# Epoch 105/999 | Loss 0.2088 | Win count 16
# Epoch 106/999 | Loss 0.2384 | Win count 16
# Epoch 107/999 | Loss 0.1904 | Win count 16
# Epoch 108/999 | Loss 0.3043 | Win count 16
# Epoch 109/999 | Loss 0.2656 | Win count 16
# Epoch 110/999 | Loss 0.2595 | Win count 16
# Epoch 111/999 | Loss 0.2133 | Win count 16
# Epoch 112/999 | Loss 0.2284 | Win count 17
# Epoch 113/999 | Loss 0.1918 | Win count 17
# Epoch 114/999 | Loss 0.2065 | Win count 18
# Epoch 115/999 | Loss 0.2694 | Win count 18
# Epoch 116/999 | Loss 0.2280 | Win count 18
# Epoch 117/999 | Loss 0.3045 | Win count 19
# Epoch 118/999 | Loss 0.2496 | Win count 19
# Epoch 119/999 | Loss 0.2300 | Win count 20
# Epoch 120/999 | Loss 0.2879 | Win count 20
# Epoch 121/999 | Loss 0.2557 | Win count 21
# Epoch 122/999 | Loss 0.2315 | Win count 22
# Epoch 123/999 | Loss 0.3182 | Win count 22
# Epoch 124/999 | Loss 0.3398 | Win count 22
# Epoch 125/999 | Loss 0.3365 | Win count 23
# Epoch 126/999 | Loss 0.3186 | Win count 23
# Epoch 127/999 | Loss 0.3014 | Win count 23
# Epoch 128/999 | Loss 0.2868 | Win count 23
# Epoch 129/999 | Loss 0.2859 | Win count 23
# Epoch 130/999 | Loss 0.2699 | Win count 23
# Epoch 131/999 | Loss 0.3074 | Win count 23
# Epoch 132/999 | Loss 0.2701 | Win count 23
# Epoch 133/999 | Loss 0.2783 | Win count 23
# Epoch 134/999 | Loss 0.2771 | Win count 23
# Epoch 135/999 | Loss 0.2053 | Win count 23
# Epoch 136/999 | Loss 0.2487 | Win count 23
# Epoch 137/999 | Loss 0.3217 | Win count 23
# Epoch 138/999 | Loss 0.2552 | Win count 23
# Epoch 139/999 | Loss 0.2333 | Win count 23
# Epoch 140/999 | Loss 0.2893 | Win count 23
# Epoch 141/999 | Loss 0.2340 | Win count 23
# Epoch 142/999 | Loss 0.2898 | Win count 23
# Epoch 143/999 | Loss 0.2975 | Win count 23
# Epoch 144/999 | Loss 0.2563 | Win count 23
# Epoch 145/999 | Loss 0.3117 | Win count 23
# Epoch 146/999 | Loss 0.2418 | Win count 23
# Epoch 147/999 | Loss 0.2399 | Win count 23
# Epoch 148/999 | Loss 0.3107 | Win count 24
# Epoch 149/999 | Loss 0.2588 | Win count 25
# Epoch 150/999 | Loss 0.3391 | Win count 25
# Epoch 151/999 | Loss 0.2766 | Win count 26
# Epoch 152/999 | Loss 0.2849 | Win count 27
# Epoch 153/999 | Loss 0.3242 | Win count 27
# Epoch 154/999 | Loss 0.2655 | Win count 27
# Epoch 155/999 | Loss 0.2916 | Win count 28
# Epoch 156/999 | Loss 0.2077 | Win count 28
# Epoch 157/999 | Loss 0.2566 | Win count 28
# Epoch 158/999 | Loss 0.2194 | Win count 29
# Epoch 159/999 | Loss 0.2963 | Win count 29
# Epoch 160/999 | Loss 0.2376 | Win count 29
# Epoch 161/999 | Loss 0.2565 | Win count 29
# Epoch 162/999 | Loss 0.2296 | Win count 29
# Epoch 163/999 | Loss 0.3366 | Win count 29
# Epoch 164/999 | Loss 0.1597 | Win count 29
# Epoch 165/999 | Loss 0.2300 | Win count 30
# Epoch 166/999 | Loss 0.2356 | Win count 31
# Epoch 167/999 | Loss 0.2212 | Win count 31
# Epoch 168/999 | Loss 0.2646 | Win count 31
# Epoch 169/999 | Loss 0.3317 | Win count 31
# Epoch 170/999 | Loss 0.2448 | Win count 31
# Epoch 171/999 | Loss 0.2724 | Win count 32
# Epoch 172/999 | Loss 0.3454 | Win count 32
# Epoch 173/999 | Loss 0.2788 | Win count 33
# Epoch 174/999 | Loss 0.3585 | Win count 33
# Epoch 175/999 | Loss 0.2272 | Win count 34
# Epoch 176/999 | Loss 0.3434 | Win count 34
# Epoch 177/999 | Loss 0.2718 | Win count 34
# Epoch 178/999 | Loss 0.3569 | Win count 34
# Epoch 179/999 | Loss 0.2657 | Win count 35
# Epoch 180/999 | Loss 0.3412 | Win count 36
# Epoch 181/999 | Loss 0.3756 | Win count 36
# Epoch 182/999 | Loss 0.4038 | Win count 36
# Epoch 183/999 | Loss 0.2642 | Win count 36
# Epoch 184/999 | Loss 0.3124 | Win count 37
# Epoch 185/999 | Loss 0.2624 | Win count 37
# Epoch 186/999 | Loss 0.2749 | Win count 38
# Epoch 187/999 | Loss 0.2845 | Win count 39
# Epoch 188/999 | Loss 0.3637 | Win count 39
# Epoch 189/999 | Loss 0.3463 | Win count 39
# Epoch 190/999 | Loss 0.3359 | Win count 40
# Epoch 191/999 | Loss 0.3101 | Win count 40
# Epoch 192/999 | Loss 0.3336 | Win count 40
# Epoch 193/999 | Loss 0.3747 | Win count 40
# Epoch 194/999 | Loss 0.2750 | Win count 40
# Epoch 195/999 | Loss 0.3659 | Win count 40
# Epoch 196/999 | Loss 0.3286 | Win count 41
# Epoch 197/999 | Loss 0.3613 | Win count 41
# Epoch 198/999 | Loss 0.2754 | Win count 41
# Epoch 199/999 | Loss 0.2864 | Win count 42
# wins in last 100: 27
# Epoch 200/999 | Loss 0.3163 | Win count 42
# Epoch 201/999 | Loss 0.3817 | Win count 42
# Epoch 202/999 | Loss 0.2859 | Win count 42
# Epoch 203/999 | Loss 0.2836 | Win count 42
# Epoch 204/999 | Loss 0.3067 | Win count 42
# Epoch 205/999 | Loss 0.3007 | Win count 42
# Epoch 206/999 | Loss 0.3024 | Win count 42
# Epoch 207/999 | Loss 0.3003 | Win count 42
# Epoch 208/999 | Loss 0.3388 | Win count 42
# Epoch 209/999 | Loss 0.2337 | Win count 42
# Epoch 210/999 | Loss 0.3099 | Win count 43
# Epoch 211/999 | Loss 0.2337 | Win count 43
# Epoch 212/999 | Loss 0.4006 | Win count 43
# Epoch 213/999 | Loss 0.2175 | Win count 43
# Epoch 214/999 | Loss 0.2570 | Win count 44
# Epoch 215/999 | Loss 0.2777 | Win count 45
# Epoch 216/999 | Loss 0.2926 | Win count 45
# Epoch 217/999 | Loss 0.2474 | Win count 45
# Epoch 218/999 | Loss 0.2900 | Win count 45
# Epoch 219/999 | Loss 0.2887 | Win count 45
# Epoch 220/999 | Loss 0.2347 | Win count 45
# Epoch 221/999 | Loss 0.2636 | Win count 45
# Epoch 222/999 | Loss 0.2303 | Win count 45
# Epoch 223/999 | Loss 0.2052 | Win count 46
# Epoch 224/999 | Loss 0.2144 | Win count 46
# Epoch 225/999 | Loss 0.2334 | Win count 46
# Epoch 226/999 | Loss 0.1993 | Win count 46
# Epoch 227/999 | Loss 0.2153 | Win count 46
# Epoch 228/999 | Loss 0.2448 | Win count 46
# Epoch 229/999 | Loss 0.2198 | Win count 46
# Epoch 230/999 | Loss 0.1897 | Win count 46
# Epoch 231/999 | Loss 0.2230 | Win count 46
# Epoch 232/999 | Loss 0.2652 | Win count 47
# Epoch 233/999 | Loss 0.1887 | Win count 48
# Epoch 234/999 | Loss 0.2086 | Win count 48
# Epoch 235/999 | Loss 0.2242 | Win count 48
# Epoch 236/999 | Loss 0.2515 | Win count 48
# Epoch 237/999 | Loss 0.2583 | Win count 49
# Epoch 238/999 | Loss 0.2680 | Win count 49
# Epoch 239/999 | Loss 0.2196 | Win count 49
# Epoch 240/999 | Loss 0.2540 | Win count 50
# Epoch 241/999 | Loss 0.2319 | Win count 50
# Epoch 242/999 | Loss 0.3243 | Win count 51
# Epoch 243/999 | Loss 0.2490 | Win count 52
# Epoch 244/999 | Loss 0.2630 | Win count 53
# Epoch 245/999 | Loss 0.3269 | Win count 54
# Epoch 246/999 | Loss 0.2965 | Win count 54
# Epoch 247/999 | Loss 0.2892 | Win count 54
# Epoch 248/999 | Loss 0.3813 | Win count 54
# Epoch 249/999 | Loss 0.2803 | Win count 54
# Epoch 250/999 | Loss 0.3344 | Win count 54
# Epoch 251/999 | Loss 0.2714 | Win count 54
# Epoch 252/999 | Loss 0.2955 | Win count 54
# Epoch 253/999 | Loss 0.2589 | Win count 54
# Epoch 254/999 | Loss 0.2706 | Win count 54
# Epoch 255/999 | Loss 0.2569 | Win count 54
# Epoch 256/999 | Loss 0.2594 | Win count 54
# Epoch 257/999 | Loss 0.3103 | Win count 54
# Epoch 258/999 | Loss 0.2880 | Win count 54
# Epoch 259/999 | Loss 0.3236 | Win count 54
# Epoch 260/999 | Loss 0.3092 | Win count 55
# Epoch 261/999 | Loss 0.2461 | Win count 55
# Epoch 262/999 | Loss 0.2671 | Win count 56
# Epoch 263/999 | Loss 0.2791 | Win count 56
# Epoch 264/999 | Loss 0.3652 | Win count 57
# Epoch 265/999 | Loss 0.2733 | Win count 58
# Epoch 266/999 | Loss 0.3812 | Win count 58
# Epoch 267/999 | Loss 0.3195 | Win count 58
# Epoch 268/999 | Loss 0.3419 | Win count 58
# Epoch 269/999 | Loss 0.2991 | Win count 58
# Epoch 270/999 | Loss 0.2409 | Win count 58
# Epoch 271/999 | Loss 0.3810 | Win count 58
# Epoch 272/999 | Loss 0.3023 | Win count 58
# Epoch 273/999 | Loss 0.3727 | Win count 58
# Epoch 274/999 | Loss 0.2181 | Win count 58
# Epoch 275/999 | Loss 0.2800 | Win count 58
# Epoch 276/999 | Loss 0.2581 | Win count 58
# Epoch 277/999 | Loss 0.2224 | Win count 58
# Epoch 278/999 | Loss 0.3118 | Win count 58
# Epoch 279/999 | Loss 0.2134 | Win count 58
# Epoch 280/999 | Loss 0.2326 | Win count 58
# Epoch 281/999 | Loss 0.1327 | Win count 58
# Epoch 282/999 | Loss 0.1778 | Win count 59
# Epoch 283/999 | Loss 0.1655 | Win count 59
# Epoch 284/999 | Loss 0.1992 | Win count 59
# Epoch 285/999 | Loss 0.1946 | Win count 60
# Epoch 286/999 | Loss 0.1764 | Win count 60
# Epoch 287/999 | Loss 0.2012 | Win count 60
# Epoch 288/999 | Loss 0.1942 | Win count 60
# Epoch 289/999 | Loss 0.2131 | Win count 60
# Epoch 290/999 | Loss 0.1848 | Win count 60
# Epoch 291/999 | Loss 0.1427 | Win count 60
# Epoch 292/999 | Loss 0.1702 | Win count 60
# Epoch 293/999 | Loss 0.1164 | Win count 60
# Epoch 294/999 | Loss 0.1517 | Win count 60
# Epoch 295/999 | Loss 0.1641 | Win count 60
# Epoch 296/999 | Loss 0.1101 | Win count 60
# Epoch 297/999 | Loss 0.1389 | Win count 60
# Epoch 298/999 | Loss 0.0988 | Win count 60
# Epoch 299/999 | Loss 0.1100 | Win count 61
# wins in last 100: 19
# Epoch 300/999 | Loss 0.0692 | Win count 61
# Epoch 301/999 | Loss 0.0937 | Win count 61
# Epoch 302/999 | Loss 0.0660 | Win count 61
# Epoch 303/999 | Loss 0.1025 | Win count 61
# Epoch 304/999 | Loss 0.0733 | Win count 61
# Epoch 305/999 | Loss 0.0642 | Win count 62
# Epoch 306/999 | Loss 0.0744 | Win count 62
# Epoch 307/999 | Loss 0.0826 | Win count 63
# Epoch 308/999 | Loss 0.1520 | Win count 63
# Epoch 309/999 | Loss 0.1372 | Win count 63
# Epoch 310/999 | Loss 0.1135 | Win count 63
# Epoch 311/999 | Loss 0.1250 | Win count 63
# Epoch 312/999 | Loss 0.1037 | Win count 64
# Epoch 313/999 | Loss 0.0755 | Win count 64
# Epoch 314/999 | Loss 0.1573 | Win count 64
# Epoch 315/999 | Loss 0.0689 | Win count 64
# Epoch 316/999 | Loss 0.1081 | Win count 64
# Epoch 317/999 | Loss 0.1029 | Win count 64
# Epoch 318/999 | Loss 0.0666 | Win count 64
# Epoch 319/999 | Loss 0.0930 | Win count 64
# Epoch 320/999 | Loss 0.1045 | Win count 64
# Epoch 321/999 | Loss 0.0627 | Win count 65
# Epoch 322/999 | Loss 0.1392 | Win count 65
# Epoch 323/999 | Loss 0.0835 | Win count 65
# Epoch 324/999 | Loss 0.0933 | Win count 65
# Epoch 325/999 | Loss 0.0712 | Win count 65
# Epoch 326/999 | Loss 0.1082 | Win count 65
# Epoch 327/999 | Loss 0.0602 | Win count 65
# Epoch 328/999 | Loss 0.0843 | Win count 65
# Epoch 329/999 | Loss 0.0678 | Win count 65
# Epoch 330/999 | Loss 0.0844 | Win count 66
# Epoch 331/999 | Loss 0.1147 | Win count 66
# Epoch 332/999 | Loss 0.0855 | Win count 66
# Epoch 333/999 | Loss 0.0908 | Win count 66
# Epoch 334/999 | Loss 0.0929 | Win count 66
# Epoch 335/999 | Loss 0.0753 | Win count 66
# Epoch 336/999 | Loss 0.0940 | Win count 66
# Epoch 337/999 | Loss 0.0436 | Win count 66
# Epoch 338/999 | Loss 0.0850 | Win count 66
# Epoch 339/999 | Loss 0.0803 | Win count 66
# Epoch 340/999 | Loss 0.0720 | Win count 66
# Epoch 341/999 | Loss 0.0707 | Win count 66
# Epoch 342/999 | Loss 0.0668 | Win count 67
# Epoch 343/999 | Loss 0.1037 | Win count 68
# Epoch 344/999 | Loss 0.0926 | Win count 68
# Epoch 345/999 | Loss 0.0785 | Win count 69
# Epoch 346/999 | Loss 0.1603 | Win count 69
# Epoch 347/999 | Loss 0.2050 | Win count 70
# Epoch 348/999 | Loss 0.2099 | Win count 71
# Epoch 349/999 | Loss 0.1098 | Win count 71
# Epoch 350/999 | Loss 0.2669 | Win count 72
# Epoch 351/999 | Loss 0.1555 | Win count 73
# Epoch 352/999 | Loss 0.2414 | Win count 73
# Epoch 353/999 | Loss 0.2522 | Win count 74
# Epoch 354/999 | Loss 0.1550 | Win count 74
# Epoch 355/999 | Loss 0.1631 | Win count 75
# Epoch 356/999 | Loss 0.2097 | Win count 76
# Epoch 357/999 | Loss 0.1934 | Win count 76
# Epoch 358/999 | Loss 0.1979 | Win count 76
# Epoch 359/999 | Loss 0.2232 | Win count 76
# Epoch 360/999 | Loss 0.2254 | Win count 76
# Epoch 361/999 | Loss 0.1807 | Win count 76
# Epoch 362/999 | Loss 0.2065 | Win count 76
# Epoch 363/999 | Loss 0.2415 | Win count 77
# Epoch 364/999 | Loss 0.2645 | Win count 77
# Epoch 365/999 | Loss 0.2453 | Win count 78
# Epoch 366/999 | Loss 0.2183 | Win count 79
# Epoch 367/999 | Loss 0.2238 | Win count 79
# Epoch 368/999 | Loss 0.2311 | Win count 79
# Epoch 369/999 | Loss 0.2808 | Win count 80
# Epoch 370/999 | Loss 0.2301 | Win count 81
# Epoch 371/999 | Loss 0.2064 | Win count 81
# Epoch 372/999 | Loss 0.1773 | Win count 81
# Epoch 373/999 | Loss 0.2138 | Win count 81
# Epoch 374/999 | Loss 0.2589 | Win count 82
# Epoch 375/999 | Loss 0.2555 | Win count 82
# Epoch 376/999 | Loss 0.2727 | Win count 82
# Epoch 377/999 | Loss 0.2994 | Win count 82
# Epoch 378/999 | Loss 0.2508 | Win count 83
# Epoch 379/999 | Loss 0.2301 | Win count 84
# Epoch 380/999 | Loss 0.1744 | Win count 84
# Epoch 381/999 | Loss 0.2248 | Win count 84
# Epoch 382/999 | Loss 0.2455 | Win count 85
# Epoch 383/999 | Loss 0.2094 | Win count 86
# Epoch 384/999 | Loss 0.1265 | Win count 86
# Epoch 385/999 | Loss 0.1819 | Win count 86
# Epoch 386/999 | Loss 0.2368 | Win count 86
# Epoch 387/999 | Loss 0.1622 | Win count 86
# Epoch 388/999 | Loss 0.1760 | Win count 87
# Epoch 389/999 | Loss 0.1799 | Win count 88
# Epoch 390/999 | Loss 0.2390 | Win count 88
# Epoch 391/999 | Loss 0.2179 | Win count 89
# Epoch 392/999 | Loss 0.2480 | Win count 89
# Epoch 393/999 | Loss 0.2126 | Win count 89
# Epoch 394/999 | Loss 0.2784 | Win count 90
# Epoch 395/999 | Loss 0.2303 | Win count 90
# Epoch 396/999 | Loss 0.2661 | Win count 90
# Epoch 397/999 | Loss 0.2271 | Win count 90
# Epoch 398/999 | Loss 0.2050 | Win count 90
# Epoch 399/999 | Loss 0.2671 | Win count 90
# wins in last 100: 29
# Epoch 400/999 | Loss 0.2655 | Win count 90
# Epoch 401/999 | Loss 0.2618 | Win count 90
# Epoch 402/999 | Loss 0.2951 | Win count 91
# Epoch 403/999 | Loss 0.2689 | Win count 92
# Epoch 404/999 | Loss 0.2256 | Win count 92
# Epoch 405/999 | Loss 0.1650 | Win count 92
# Epoch 406/999 | Loss 0.2470 | Win count 92
# Epoch 407/999 | Loss 0.1440 | Win count 92
# Epoch 408/999 | Loss 0.1156 | Win count 92
# Epoch 409/999 | Loss 0.1627 | Win count 93
# Epoch 410/999 | Loss 0.1553 | Win count 93
# Epoch 411/999 | Loss 0.2028 | Win count 93
# Epoch 412/999 | Loss 0.1454 | Win count 93
# Epoch 413/999 | Loss 0.1542 | Win count 94
# Epoch 414/999 | Loss 0.2387 | Win count 94
# Epoch 415/999 | Loss 0.1830 | Win count 95
# Epoch 416/999 | Loss 0.2142 | Win count 95
# Epoch 417/999 | Loss 0.2218 | Win count 95
# Epoch 418/999 | Loss 0.2328 | Win count 95
# Epoch 419/999 | Loss 0.1430 | Win count 96
# Epoch 420/999 | Loss 0.2037 | Win count 96
# Epoch 421/999 | Loss 0.2950 | Win count 96
# Epoch 422/999 | Loss 0.1276 | Win count 96
# Epoch 423/999 | Loss 0.1132 | Win count 96
# Epoch 424/999 | Loss 0.2017 | Win count 96
# Epoch 425/999 | Loss 0.2101 | Win count 96
# Epoch 426/999 | Loss 0.2131 | Win count 96
# Epoch 427/999 | Loss 0.2507 | Win count 96
# Epoch 428/999 | Loss 0.2580 | Win count 96
# Epoch 429/999 | Loss 0.1812 | Win count 96
# Epoch 430/999 | Loss 0.2523 | Win count 96
# Epoch 431/999 | Loss 0.1948 | Win count 96
# Epoch 432/999 | Loss 0.1721 | Win count 96
# Epoch 433/999 | Loss 0.1858 | Win count 96
# Epoch 434/999 | Loss 0.1812 | Win count 96
# Epoch 435/999 | Loss 0.1727 | Win count 96
# Epoch 436/999 | Loss 0.2147 | Win count 96
# Epoch 437/999 | Loss 0.1985 | Win count 96
# Epoch 438/999 | Loss 0.1425 | Win count 96
# Epoch 439/999 | Loss 0.1392 | Win count 96
# Epoch 440/999 | Loss 0.1694 | Win count 97
# Epoch 441/999 | Loss 0.2778 | Win count 97
# Epoch 442/999 | Loss 0.1845 | Win count 97
# Epoch 443/999 | Loss 0.2057 | Win count 98
# Epoch 444/999 | Loss 0.2540 | Win count 98
# Epoch 445/999 | Loss 0.2827 | Win count 99
# Epoch 446/999 | Loss 0.1900 | Win count 99
# Epoch 447/999 | Loss 0.3130 | Win count 99
# Epoch 448/999 | Loss 0.2555 | Win count 100
# Epoch 449/999 | Loss 0.2052 | Win count 100
# Epoch 450/999 | Loss 0.2200 | Win count 100
# Epoch 451/999 | Loss 0.2245 | Win count 100
# Epoch 452/999 | Loss 0.1612 | Win count 100
# Epoch 453/999 | Loss 0.2379 | Win count 100
# Epoch 454/999 | Loss 0.1547 | Win count 100
# Epoch 455/999 | Loss 0.1357 | Win count 100
# Epoch 456/999 | Loss 0.0726 | Win count 100
# Epoch 457/999 | Loss 0.1333 | Win count 100
# Epoch 458/999 | Loss 0.1912 | Win count 101
# Epoch 459/999 | Loss 0.2545 | Win count 101
# Epoch 460/999 | Loss 0.2521 | Win count 101
# Epoch 461/999 | Loss 0.1370 | Win count 101
# Epoch 462/999 | Loss 0.1640 | Win count 101
# Epoch 463/999 | Loss 0.1621 | Win count 102
# Epoch 464/999 | Loss 0.2911 | Win count 102
# Epoch 465/999 | Loss 0.1726 | Win count 102
# Epoch 466/999 | Loss 0.1594 | Win count 102
# Epoch 467/999 | Loss 0.1850 | Win count 102
# Epoch 468/999 | Loss 0.2237 | Win count 102
# Epoch 469/999 | Loss 0.2586 | Win count 102
# Epoch 470/999 | Loss 0.1681 | Win count 102
# Epoch 471/999 | Loss 0.2187 | Win count 102
# Epoch 472/999 | Loss 0.1675 | Win count 102
# Epoch 473/999 | Loss 0.1596 | Win count 103
# Epoch 474/999 | Loss 0.1885 | Win count 103
# Epoch 475/999 | Loss 0.1494 | Win count 103
# Epoch 476/999 | Loss 0.1988 | Win count 103
# Epoch 477/999 | Loss 0.1799 | Win count 103
# Epoch 478/999 | Loss 0.1159 | Win count 103
# Epoch 479/999 | Loss 0.1005 | Win count 104
# Epoch 480/999 | Loss 0.1534 | Win count 104
# Epoch 481/999 | Loss 0.1659 | Win count 104
# Epoch 482/999 | Loss 0.1460 | Win count 104
# Epoch 483/999 | Loss 0.0913 | Win count 104
# Epoch 484/999 | Loss 0.1005 | Win count 105
# Epoch 485/999 | Loss 0.0967 | Win count 105
# Epoch 486/999 | Loss 0.1613 | Win count 105
# Epoch 487/999 | Loss 0.1064 | Win count 105
# Epoch 488/999 | Loss 0.1386 | Win count 105
# Epoch 489/999 | Loss 0.1093 | Win count 105
# Epoch 490/999 | Loss 0.1502 | Win count 106
# Epoch 491/999 | Loss 0.1099 | Win count 106
# Epoch 492/999 | Loss 0.1578 | Win count 106
# Epoch 493/999 | Loss 0.1862 | Win count 106
# Epoch 494/999 | Loss 0.2332 | Win count 107
# Epoch 495/999 | Loss 0.1481 | Win count 107
# Epoch 496/999 | Loss 0.2567 | Win count 107
# Epoch 497/999 | Loss 0.2014 | Win count 107
# Epoch 498/999 | Loss 0.2618 | Win count 108
# Epoch 499/999 | Loss 0.2335 | Win count 108
# wins in last 100: 19
# Epoch 500/999 | Loss 0.1824 | Win count 109
# Epoch 501/999 | Loss 0.1865 | Win count 109
# Epoch 502/999 | Loss 0.2438 | Win count 109
# Epoch 503/999 | Loss 0.2455 | Win count 110
# Epoch 504/999 | Loss 0.2145 | Win count 110
# Epoch 505/999 | Loss 0.2498 | Win count 110
# Epoch 506/999 | Loss 0.1656 | Win count 110
# Epoch 507/999 | Loss 0.1342 | Win count 110
# Epoch 508/999 | Loss 0.2597 | Win count 111
# Epoch 509/999 | Loss 0.1850 | Win count 111
# Epoch 510/999 | Loss 0.2277 | Win count 111
# Epoch 511/999 | Loss 0.2082 | Win count 111
# Epoch 512/999 | Loss 0.2335 | Win count 112
# Epoch 513/999 | Loss 0.2023 | Win count 112
# Epoch 514/999 | Loss 0.1998 | Win count 112
# Epoch 515/999 | Loss 0.1929 | Win count 112
# Epoch 516/999 | Loss 0.1523 | Win count 112
# Epoch 517/999 | Loss 0.1421 | Win count 113
# Epoch 518/999 | Loss 0.1413 | Win count 113
# Epoch 519/999 | Loss 0.2401 | Win count 113
# Epoch 520/999 | Loss 0.1766 | Win count 114
# Epoch 521/999 | Loss 0.1843 | Win count 114
# Epoch 522/999 | Loss 0.1969 | Win count 114
# Epoch 523/999 | Loss 0.1804 | Win count 114
# Epoch 524/999 | Loss 0.1914 | Win count 114
# Epoch 525/999 | Loss 0.2126 | Win count 114
# Epoch 526/999 | Loss 0.2914 | Win count 114
# Epoch 527/999 | Loss 0.2333 | Win count 114
# Epoch 528/999 | Loss 0.2692 | Win count 114
# Epoch 529/999 | Loss 0.1903 | Win count 114
# Epoch 530/999 | Loss 0.2159 | Win count 114
# Epoch 531/999 | Loss 0.2249 | Win count 115
# Epoch 532/999 | Loss 0.2038 | Win count 116
# Epoch 533/999 | Loss 0.1849 | Win count 116
# Epoch 534/999 | Loss 0.1827 | Win count 116
# Epoch 535/999 | Loss 0.1056 | Win count 117
# Epoch 536/999 | Loss 0.1923 | Win count 117
# Epoch 537/999 | Loss 0.1591 | Win count 117
# Epoch 538/999 | Loss 0.1517 | Win count 117
# Epoch 539/999 | Loss 0.1573 | Win count 118
# Epoch 540/999 | Loss 0.2109 | Win count 119
# Epoch 541/999 | Loss 0.1776 | Win count 119
# Epoch 542/999 | Loss 0.2640 | Win count 119
# Epoch 543/999 | Loss 0.2887 | Win count 119
# Epoch 544/999 | Loss 0.1623 | Win count 119
# Epoch 545/999 | Loss 0.2029 | Win count 119
# Epoch 546/999 | Loss 0.1309 | Win count 119
# Epoch 547/999 | Loss 0.1613 | Win count 120
# Epoch 548/999 | Loss 0.1755 | Win count 120
# Epoch 549/999 | Loss 0.1546 | Win count 120
# Epoch 550/999 | Loss 0.1705 | Win count 120
# Epoch 551/999 | Loss 0.2380 | Win count 120
# Epoch 552/999 | Loss 0.1764 | Win count 120
# Epoch 553/999 | Loss 0.1629 | Win count 120
# Epoch 554/999 | Loss 0.1994 | Win count 120
# Epoch 555/999 | Loss 0.1834 | Win count 121
# Epoch 556/999 | Loss 0.2086 | Win count 121
# Epoch 557/999 | Loss 0.3203 | Win count 122
# Epoch 558/999 | Loss 0.1680 | Win count 122
# Epoch 559/999 | Loss 0.2762 | Win count 122
# Epoch 560/999 | Loss 0.1365 | Win count 123
# Epoch 561/999 | Loss 0.2607 | Win count 123
# Epoch 562/999 | Loss 0.3022 | Win count 123
# Epoch 563/999 | Loss 0.2669 | Win count 123
# Epoch 564/999 | Loss 0.2806 | Win count 123
# Epoch 565/999 | Loss 0.3053 | Win count 123
# Epoch 566/999 | Loss 0.2355 | Win count 124
# Epoch 567/999 | Loss 0.2387 | Win count 125
# Epoch 568/999 | Loss 0.2500 | Win count 125
# Epoch 569/999 | Loss 0.1772 | Win count 126
# Epoch 570/999 | Loss 0.2977 | Win count 126
# Epoch 571/999 | Loss 0.3039 | Win count 126
# Epoch 572/999 | Loss 0.1858 | Win count 126
# Epoch 573/999 | Loss 0.2791 | Win count 126
# Epoch 574/999 | Loss 0.0989 | Win count 126
# Epoch 575/999 | Loss 0.2469 | Win count 126
# Epoch 576/999 | Loss 0.1626 | Win count 126
# Epoch 577/999 | Loss 0.2741 | Win count 126
# Epoch 578/999 | Loss 0.2213 | Win count 127
# Epoch 579/999 | Loss 0.1374 | Win count 128
# Epoch 580/999 | Loss 0.1690 | Win count 128
# Epoch 581/999 | Loss 0.1784 | Win count 129
# Epoch 582/999 | Loss 0.2533 | Win count 129
# Epoch 583/999 | Loss 0.2103 | Win count 129
# Epoch 584/999 | Loss 0.2400 | Win count 130
# Epoch 585/999 | Loss 0.2525 | Win count 130
# Epoch 586/999 | Loss 0.2320 | Win count 130
# Epoch 587/999 | Loss 0.2234 | Win count 130
# Epoch 588/999 | Loss 0.2561 | Win count 130
# Epoch 589/999 | Loss 0.3044 | Win count 130
# Epoch 590/999 | Loss 0.2528 | Win count 130
# Epoch 591/999 | Loss 0.2082 | Win count 130
# Epoch 592/999 | Loss 0.1586 | Win count 131
# Epoch 593/999 | Loss 0.1447 | Win count 131
# Epoch 594/999 | Loss 0.1870 | Win count 131
# Epoch 595/999 | Loss 0.2658 | Win count 131
# Epoch 596/999 | Loss 0.1773 | Win count 131
# Epoch 597/999 | Loss 0.1474 | Win count 131
# Epoch 598/999 | Loss 0.1716 | Win count 132
# Epoch 599/999 | Loss 0.1946 | Win count 132
# wins in last 100: 24
# Epoch 600/999 | Loss 0.1988 | Win count 133
# Epoch 601/999 | Loss 0.1863 | Win count 133
# Epoch 602/999 | Loss 0.1997 | Win count 134
# Epoch 603/999 | Loss 0.1461 | Win count 134
# Epoch 604/999 | Loss 0.1774 | Win count 135
# Epoch 605/999 | Loss 0.2358 | Win count 136
# Epoch 606/999 | Loss 0.3254 | Win count 136
# Epoch 607/999 | Loss 0.2926 | Win count 137
# Epoch 608/999 | Loss 0.2681 | Win count 137
# Epoch 609/999 | Loss 0.2271 | Win count 137
# Epoch 610/999 | Loss 0.2736 | Win count 138
# Epoch 611/999 | Loss 0.2175 | Win count 138
# Epoch 612/999 | Loss 0.2876 | Win count 138
# Epoch 613/999 | Loss 0.2621 | Win count 138
# Epoch 614/999 | Loss 0.2640 | Win count 138
# Epoch 615/999 | Loss 0.2993 | Win count 138
# Epoch 616/999 | Loss 0.1969 | Win count 139
# Epoch 617/999 | Loss 0.3255 | Win count 139
# Epoch 618/999 | Loss 0.2514 | Win count 140
# Epoch 619/999 | Loss 0.3193 | Win count 141
# Epoch 620/999 | Loss 0.2738 | Win count 141
# Epoch 621/999 | Loss 0.2201 | Win count 141
# Epoch 622/999 | Loss 0.2644 | Win count 141
# Epoch 623/999 | Loss 0.2763 | Win count 141
# Epoch 624/999 | Loss 0.2769 | Win count 141
# Epoch 625/999 | Loss 0.2895 | Win count 142
# Epoch 626/999 | Loss 0.2820 | Win count 142
# Epoch 627/999 | Loss 0.2478 | Win count 143
# Epoch 628/999 | Loss 0.1882 | Win count 144
# Epoch 629/999 | Loss 0.2701 | Win count 144
# Epoch 630/999 | Loss 0.2448 | Win count 144
# Epoch 631/999 | Loss 0.3025 | Win count 144
# Epoch 632/999 | Loss 0.2379 | Win count 145
# Epoch 633/999 | Loss 0.3748 | Win count 145
# Epoch 634/999 | Loss 0.2957 | Win count 145
# Epoch 635/999 | Loss 0.3063 | Win count 145
# Epoch 636/999 | Loss 0.2780 | Win count 145
# Epoch 637/999 | Loss 0.1910 | Win count 145
# Epoch 638/999 | Loss 0.2392 | Win count 145
# Epoch 639/999 | Loss 0.1965 | Win count 145
# Epoch 640/999 | Loss 0.1425 | Win count 146
# Epoch 641/999 | Loss 0.1146 | Win count 146
# Epoch 642/999 | Loss 0.2095 | Win count 146
# Epoch 643/999 | Loss 0.2547 | Win count 147
# Epoch 644/999 | Loss 0.1708 | Win count 147
# Epoch 645/999 | Loss 0.1815 | Win count 147
# Epoch 646/999 | Loss 0.2588 | Win count 148
# Epoch 647/999 | Loss 0.1624 | Win count 148
# Epoch 648/999 | Loss 0.1901 | Win count 148
# Epoch 649/999 | Loss 0.1098 | Win count 148
# Epoch 650/999 | Loss 0.1610 | Win count 149
# Epoch 651/999 | Loss 0.1842 | Win count 149
# Epoch 652/999 | Loss 0.2640 | Win count 149
# Epoch 653/999 | Loss 0.1852 | Win count 150
# Epoch 654/999 | Loss 0.1724 | Win count 150
# Epoch 655/999 | Loss 0.2529 | Win count 150
# Epoch 656/999 | Loss 0.2159 | Win count 150
# Epoch 657/999 | Loss 0.1944 | Win count 150
# Epoch 658/999 | Loss 0.2425 | Win count 150
# Epoch 659/999 | Loss 0.1786 | Win count 150
# Epoch 660/999 | Loss 0.2195 | Win count 150
# Epoch 661/999 | Loss 0.1393 | Win count 150
# Epoch 662/999 | Loss 0.1234 | Win count 150
# Epoch 663/999 | Loss 0.1702 | Win count 150
# Epoch 664/999 | Loss 0.1741 | Win count 150
# Epoch 665/999 | Loss 0.2404 | Win count 150
# Epoch 666/999 | Loss 0.1855 | Win count 150
# Epoch 667/999 | Loss 0.2521 | Win count 150
# Epoch 668/999 | Loss 0.2128 | Win count 150
# Epoch 669/999 | Loss 0.1450 | Win count 150
# Epoch 670/999 | Loss 0.1777 | Win count 150
# Epoch 671/999 | Loss 0.1424 | Win count 150
# Epoch 672/999 | Loss 0.1829 | Win count 150
# Epoch 673/999 | Loss 0.2441 | Win count 150
# Epoch 674/999 | Loss 0.1513 | Win count 150
# Epoch 675/999 | Loss 0.1850 | Win count 150
# Epoch 676/999 | Loss 0.1098 | Win count 150
# Epoch 677/999 | Loss 0.1108 | Win count 150
# Epoch 678/999 | Loss 0.1543 | Win count 150
# Epoch 679/999 | Loss 0.1257 | Win count 151
# Epoch 680/999 | Loss 0.0773 | Win count 151
# Epoch 681/999 | Loss 0.1990 | Win count 151
# Epoch 682/999 | Loss 0.1763 | Win count 151
# Epoch 683/999 | Loss 0.0565 | Win count 151
# Epoch 684/999 | Loss 0.1615 | Win count 151
# Epoch 685/999 | Loss 0.1009 | Win count 151
# Epoch 686/999 | Loss 0.0685 | Win count 151
# Epoch 687/999 | Loss 0.0697 | Win count 152
# Epoch 688/999 | Loss 0.1125 | Win count 152
# Epoch 689/999 | Loss 0.1306 | Win count 152
# Epoch 690/999 | Loss 0.1299 | Win count 152
# Epoch 691/999 | Loss 0.1411 | Win count 152
# Epoch 692/999 | Loss 0.1113 | Win count 153
# Epoch 693/999 | Loss 0.1202 | Win count 153
# Epoch 694/999 | Loss 0.0471 | Win count 153
# Epoch 695/999 | Loss 0.0892 | Win count 153
# Epoch 696/999 | Loss 0.0829 | Win count 153
# Epoch 697/999 | Loss 0.1038 | Win count 153
# Epoch 698/999 | Loss 0.0977 | Win count 153
# Epoch 699/999 | Loss 0.0582 | Win count 153
# wins in last 100: 21
# Epoch 700/999 | Loss 0.1103 | Win count 154
# Epoch 701/999 | Loss 0.0952 | Win count 155
# Epoch 702/999 | Loss 0.1855 | Win count 155
# Epoch 703/999 | Loss 0.1577 | Win count 155
# Epoch 704/999 | Loss 0.1868 | Win count 155
# Epoch 705/999 | Loss 0.1501 | Win count 155
# Epoch 706/999 | Loss 0.2239 | Win count 155
# Epoch 707/999 | Loss 0.1757 | Win count 156
# Epoch 708/999 | Loss 0.1556 | Win count 156
# Epoch 709/999 | Loss 0.1699 | Win count 157
# Epoch 710/999 | Loss 0.1965 | Win count 157
# Epoch 711/999 | Loss 0.1447 | Win count 157
# Epoch 712/999 | Loss 0.2061 | Win count 157
# Epoch 713/999 | Loss 0.1718 | Win count 157
# Epoch 714/999 | Loss 0.2560 | Win count 157
# Epoch 715/999 | Loss 0.2123 | Win count 158
# Epoch 716/999 | Loss 0.2531 | Win count 158
# Epoch 717/999 | Loss 0.1775 | Win count 158
# Epoch 718/999 | Loss 0.2362 | Win count 158
# Epoch 719/999 | Loss 0.0923 | Win count 159
# Epoch 720/999 | Loss 0.2576 | Win count 159
# Epoch 721/999 | Loss 0.2660 | Win count 159
# Epoch 722/999 | Loss 0.2239 | Win count 159
# Epoch 723/999 | Loss 0.1740 | Win count 159
# Epoch 724/999 | Loss 0.1937 | Win count 159
# Epoch 725/999 | Loss 0.1838 | Win count 159
# Epoch 726/999 | Loss 0.1614 | Win count 159
# Epoch 727/999 | Loss 0.1855 | Win count 159
# Epoch 728/999 | Loss 0.1347 | Win count 160
# Epoch 729/999 | Loss 0.1788 | Win count 160
# Epoch 730/999 | Loss 0.1152 | Win count 160
# Epoch 731/999 | Loss 0.1921 | Win count 161
# Epoch 732/999 | Loss 0.3183 | Win count 161
# Epoch 733/999 | Loss 0.2119 | Win count 162
# Epoch 734/999 | Loss 0.1808 | Win count 162
# Epoch 735/999 | Loss 0.3023 | Win count 162
# Epoch 736/999 | Loss 0.2041 | Win count 162
# Epoch 737/999 | Loss 0.1653 | Win count 162
# Epoch 738/999 | Loss 0.1615 | Win count 162
# Epoch 739/999 | Loss 0.1985 | Win count 162
# Epoch 740/999 | Loss 0.1800 | Win count 162
# Epoch 741/999 | Loss 0.1772 | Win count 162
# Epoch 742/999 | Loss 0.1872 | Win count 162
# Epoch 743/999 | Loss 0.2541 | Win count 162
# Epoch 744/999 | Loss 0.1821 | Win count 162
# Epoch 745/999 | Loss 0.1511 | Win count 162
# Epoch 746/999 | Loss 0.1632 | Win count 162
# Epoch 747/999 | Loss 0.1646 | Win count 162
# Epoch 748/999 | Loss 0.1969 | Win count 163
# Epoch 749/999 | Loss 0.2291 | Win count 163
# Epoch 750/999 | Loss 0.1971 | Win count 163
# Epoch 751/999 | Loss 0.1706 | Win count 164
# Epoch 752/999 | Loss 0.1343 | Win count 165
# Epoch 753/999 | Loss 0.1795 | Win count 165
# Epoch 754/999 | Loss 0.1785 | Win count 165
# Epoch 755/999 | Loss 0.3137 | Win count 165
# Epoch 756/999 | Loss 0.1738 | Win count 165
# Epoch 757/999 | Loss 0.2298 | Win count 165
# Epoch 758/999 | Loss 0.1770 | Win count 165
# Epoch 759/999 | Loss 0.2265 | Win count 165
# Epoch 760/999 | Loss 0.2285 | Win count 166
# Epoch 761/999 | Loss 0.2046 | Win count 166
# Epoch 762/999 | Loss 0.2029 | Win count 166
# Epoch 763/999 | Loss 0.2366 | Win count 166
# Epoch 764/999 | Loss 0.2101 | Win count 167
# Epoch 765/999 | Loss 0.2762 | Win count 167
# Epoch 766/999 | Loss 0.1682 | Win count 167
# Epoch 767/999 | Loss 0.2151 | Win count 167
# Epoch 768/999 | Loss 0.1485 | Win count 167
# Epoch 769/999 | Loss 0.1328 | Win count 168
# Epoch 770/999 | Loss 0.1118 | Win count 168
# Epoch 771/999 | Loss 0.2042 | Win count 168
# Epoch 772/999 | Loss 0.1528 | Win count 168
# Epoch 773/999 | Loss 0.0657 | Win count 168
# Epoch 774/999 | Loss 0.2172 | Win count 169
# Epoch 775/999 | Loss 0.2667 | Win count 170
# Epoch 776/999 | Loss 0.1274 | Win count 170
# Epoch 777/999 | Loss 0.1756 | Win count 170
# Epoch 778/999 | Loss 0.1480 | Win count 170
# Epoch 779/999 | Loss 0.1280 | Win count 170
# Epoch 780/999 | Loss 0.1363 | Win count 170
# Epoch 781/999 | Loss 0.1234 | Win count 170
# Epoch 782/999 | Loss 0.1191 | Win count 171
# Epoch 783/999 | Loss 0.1889 | Win count 172
# Epoch 784/999 | Loss 0.1549 | Win count 172
# Epoch 785/999 | Loss 0.1418 | Win count 172
# Epoch 786/999 | Loss 0.2070 | Win count 172
# Epoch 787/999 | Loss 0.1006 | Win count 172
# Epoch 788/999 | Loss 0.0872 | Win count 172
# Epoch 789/999 | Loss 0.1339 | Win count 172
# Epoch 790/999 | Loss 0.0889 | Win count 172
# Epoch 791/999 | Loss 0.1399 | Win count 173
# Epoch 792/999 | Loss 0.1769 | Win count 173
# Epoch 793/999 | Loss 0.1705 | Win count 174
# Epoch 794/999 | Loss 0.1562 | Win count 174
# Epoch 795/999 | Loss 0.2060 | Win count 174
# Epoch 796/999 | Loss 0.1561 | Win count 174
# Epoch 797/999 | Loss 0.1568 | Win count 174
# Epoch 798/999 | Loss 0.1417 | Win count 175
# Epoch 799/999 | Loss 0.1601 | Win count 176
# wins in last 100: 22
# Epoch 800/999 | Loss 0.1560 | Win count 176
# Epoch 801/999 | Loss 0.1688 | Win count 176
# Epoch 802/999 | Loss 0.1574 | Win count 176
# Epoch 803/999 | Loss 0.1609 | Win count 176
# Epoch 804/999 | Loss 0.1397 | Win count 176
# Epoch 805/999 | Loss 0.2129 | Win count 176
# Epoch 806/999 | Loss 0.2090 | Win count 176
# Epoch 807/999 | Loss 0.1689 | Win count 177
# Epoch 808/999 | Loss 0.1102 | Win count 177
# Epoch 809/999 | Loss 0.1858 | Win count 177
# Epoch 810/999 | Loss 0.1468 | Win count 177
# Epoch 811/999 | Loss 0.2277 | Win count 177
# Epoch 812/999 | Loss 0.1948 | Win count 177
# Epoch 813/999 | Loss 0.1856 | Win count 177
# Epoch 814/999 | Loss 0.1175 | Win count 177
# Epoch 815/999 | Loss 0.1814 | Win count 177
# Epoch 816/999 | Loss 0.1204 | Win count 177
# Epoch 817/999 | Loss 0.1555 | Win count 177
# Epoch 818/999 | Loss 0.1277 | Win count 177
# Epoch 819/999 | Loss 0.1464 | Win count 177
# Epoch 820/999 | Loss 0.0933 | Win count 177
# Epoch 821/999 | Loss 0.1052 | Win count 177
# Epoch 822/999 | Loss 0.1268 | Win count 177
# Epoch 823/999 | Loss 0.1808 | Win count 177
# Epoch 824/999 | Loss 0.1487 | Win count 177
# Epoch 825/999 | Loss 0.1739 | Win count 177
# Epoch 826/999 | Loss 0.1501 | Win count 178
# Epoch 827/999 | Loss 0.0982 | Win count 178
# Epoch 828/999 | Loss 0.1348 | Win count 178
# Epoch 829/999 | Loss 0.1375 | Win count 178
# Epoch 830/999 | Loss 0.0954 | Win count 178
# Epoch 831/999 | Loss 0.1611 | Win count 178
# Epoch 832/999 | Loss 0.0886 | Win count 178
# Epoch 833/999 | Loss 0.0866 | Win count 178
# Epoch 834/999 | Loss 0.0759 | Win count 178
# Epoch 835/999 | Loss 0.0512 | Win count 178
# Epoch 836/999 | Loss 0.0336 | Win count 178
# Epoch 837/999 | Loss 0.0817 | Win count 178
# Epoch 838/999 | Loss 0.0544 | Win count 179
# Epoch 839/999 | Loss 0.0532 | Win count 179
# Epoch 840/999 | Loss 0.1561 | Win count 180
# Epoch 841/999 | Loss 0.1066 | Win count 180
# Epoch 842/999 | Loss 0.1057 | Win count 181
# Epoch 843/999 | Loss 0.1341 | Win count 181
# Epoch 844/999 | Loss 0.2044 | Win count 182
# Epoch 845/999 | Loss 0.1735 | Win count 182
# Epoch 846/999 | Loss 0.1140 | Win count 182
# Epoch 847/999 | Loss 0.1787 | Win count 182
# Epoch 848/999 | Loss 0.1245 | Win count 183
# Epoch 849/999 | Loss 0.1503 | Win count 183
# Epoch 850/999 | Loss 0.1417 | Win count 184
# Epoch 851/999 | Loss 0.1611 | Win count 184
# Epoch 852/999 | Loss 0.1252 | Win count 184
# Epoch 853/999 | Loss 0.1851 | Win count 184
# Epoch 854/999 | Loss 0.1578 | Win count 184
# Epoch 855/999 | Loss 0.1679 | Win count 184
# Epoch 856/999 | Loss 0.1210 | Win count 184
# Epoch 857/999 | Loss 0.1502 | Win count 184
# Epoch 858/999 | Loss 0.1160 | Win count 184
# Epoch 859/999 | Loss 0.1505 | Win count 184
# Epoch 860/999 | Loss 0.1312 | Win count 184
# Epoch 861/999 | Loss 0.0966 | Win count 184
# Epoch 862/999 | Loss 0.0783 | Win count 184
# Epoch 863/999 | Loss 0.1255 | Win count 185
# Epoch 864/999 | Loss 0.1070 | Win count 185
# Epoch 865/999 | Loss 0.1180 | Win count 185
# Epoch 866/999 | Loss 0.1390 | Win count 185
# Epoch 867/999 | Loss 0.1156 | Win count 185
# Epoch 868/999 | Loss 0.1154 | Win count 186
# Epoch 869/999 | Loss 0.1861 | Win count 186
# Epoch 870/999 | Loss 0.1330 | Win count 187
# Epoch 871/999 | Loss 0.2464 | Win count 188
# Epoch 872/999 | Loss 0.2503 | Win count 188
# Epoch 873/999 | Loss 0.2197 | Win count 189
# Epoch 874/999 | Loss 0.2424 | Win count 189
# Epoch 875/999 | Loss 0.1824 | Win count 190
# Epoch 876/999 | Loss 0.1903 | Win count 190
# Epoch 877/999 | Loss 0.1807 | Win count 191
# Epoch 878/999 | Loss 0.2476 | Win count 191
# Epoch 879/999 | Loss 0.1684 | Win count 192
# Epoch 880/999 | Loss 0.2154 | Win count 193
# Epoch 881/999 | Loss 0.2314 | Win count 193
# Epoch 882/999 | Loss 0.2274 | Win count 193
# Epoch 883/999 | Loss 0.1383 | Win count 193
# Epoch 884/999 | Loss 0.2392 | Win count 193
# Epoch 885/999 | Loss 0.1510 | Win count 193
# Epoch 886/999 | Loss 0.2157 | Win count 194
# Epoch 887/999 | Loss 0.2421 | Win count 194
# Epoch 888/999 | Loss 0.2541 | Win count 194
# Epoch 889/999 | Loss 0.2383 | Win count 195
# Epoch 890/999 | Loss 0.3113 | Win count 195
# Epoch 891/999 | Loss 0.2781 | Win count 195
# Epoch 892/999 | Loss 0.1235 | Win count 195
# Epoch 893/999 | Loss 0.2786 | Win count 195
# Epoch 894/999 | Loss 0.2290 | Win count 195
# Epoch 895/999 | Loss 0.2384 | Win count 195
# Epoch 896/999 | Loss 0.2149 | Win count 195
# Epoch 897/999 | Loss 0.2658 | Win count 195
# Epoch 898/999 | Loss 0.2933 | Win count 195
# Epoch 899/999 | Loss 0.2872 | Win count 196
# wins in last 100: 20
# Epoch 900/999 | Loss 0.3217 | Win count 196
# Epoch 901/999 | Loss 0.2385 | Win count 196
# Epoch 902/999 | Loss 0.2060 | Win count 196
# Epoch 903/999 | Loss 0.2667 | Win count 196
# Epoch 904/999 | Loss 0.1591 | Win count 196
# Epoch 905/999 | Loss 0.1245 | Win count 197
# Epoch 906/999 | Loss 0.3192 | Win count 198
# Epoch 907/999 | Loss 0.2307 | Win count 198
# Epoch 908/999 | Loss 0.2198 | Win count 198
# Epoch 909/999 | Loss 0.2679 | Win count 198
# Epoch 910/999 | Loss 0.2125 | Win count 198
# Epoch 911/999 | Loss 0.1161 | Win count 198
# Epoch 912/999 | Loss 0.1525 | Win count 198
# Epoch 913/999 | Loss 0.1550 | Win count 198
# Epoch 914/999 | Loss 0.1892 | Win count 198
# Epoch 915/999 | Loss 0.1476 | Win count 198
# Epoch 916/999 | Loss 0.1505 | Win count 198
# Epoch 917/999 | Loss 0.1445 | Win count 198
# Epoch 918/999 | Loss 0.0767 | Win count 198
# Epoch 919/999 | Loss 0.1172 | Win count 198
# Epoch 920/999 | Loss 0.0974 | Win count 198
# Epoch 921/999 | Loss 0.1103 | Win count 198
# Epoch 922/999 | Loss 0.1215 | Win count 198
# Epoch 923/999 | Loss 0.1230 | Win count 198
# Epoch 924/999 | Loss 0.1628 | Win count 198
# Epoch 925/999 | Loss 0.1474 | Win count 199
# Epoch 926/999 | Loss 0.0935 | Win count 200
# Epoch 927/999 | Loss 0.1163 | Win count 201
# Epoch 928/999 | Loss 0.1425 | Win count 201
# Epoch 929/999 | Loss 0.0965 | Win count 202
# Epoch 930/999 | Loss 0.0940 | Win count 203
# Epoch 931/999 | Loss 0.0486 | Win count 203
# Epoch 932/999 | Loss 0.0567 | Win count 203
# Epoch 933/999 | Loss 0.0802 | Win count 203
# Epoch 934/999 | Loss 0.1267 | Win count 203
# Epoch 935/999 | Loss 0.1418 | Win count 204
# Epoch 936/999 | Loss 0.1126 | Win count 205
# Epoch 937/999 | Loss 0.0965 | Win count 205
# Epoch 938/999 | Loss 0.0575 | Win count 205
# Epoch 939/999 | Loss 0.0823 | Win count 205
# Epoch 940/999 | Loss 0.0657 | Win count 206
# Epoch 941/999 | Loss 0.0570 | Win count 206
# Epoch 942/999 | Loss 0.0314 | Win count 207
# Epoch 943/999 | Loss 0.0455 | Win count 208
# Epoch 944/999 | Loss 0.0551 | Win count 208
# Epoch 945/999 | Loss 0.0646 | Win count 208
# Epoch 946/999 | Loss 0.0588 | Win count 208
# Epoch 947/999 | Loss 0.0855 | Win count 209
# Epoch 948/999 | Loss 0.1241 | Win count 209
# Epoch 949/999 | Loss 0.1176 | Win count 210
# Epoch 950/999 | Loss 0.0778 | Win count 210
# Epoch 951/999 | Loss 0.1451 | Win count 211
# Epoch 952/999 | Loss 0.0744 | Win count 211
# Epoch 953/999 | Loss 0.1784 | Win count 211
# Epoch 954/999 | Loss 0.2474 | Win count 212
# Epoch 955/999 | Loss 0.1968 | Win count 212
# Epoch 956/999 | Loss 0.2628 | Win count 212
# Epoch 957/999 | Loss 0.1646 | Win count 212
# Epoch 958/999 | Loss 0.1316 | Win count 212
# Epoch 959/999 | Loss 0.2044 | Win count 212
# Epoch 960/999 | Loss 0.1280 | Win count 212
# Epoch 961/999 | Loss 0.2412 | Win count 212
# Epoch 962/999 | Loss 0.0845 | Win count 212
# Epoch 963/999 | Loss 0.1804 | Win count 213
# Epoch 964/999 | Loss 0.1336 | Win count 214
# Epoch 965/999 | Loss 0.1943 | Win count 215
# Epoch 966/999 | Loss 0.1239 | Win count 215
# Epoch 967/999 | Loss 0.1293 | Win count 216
# Epoch 968/999 | Loss 0.1883 | Win count 217
# Epoch 969/999 | Loss 0.1899 | Win count 217
# Epoch 970/999 | Loss 0.1780 | Win count 217
# Epoch 971/999 | Loss 0.1378 | Win count 218
# Epoch 972/999 | Loss 0.2528 | Win count 218
# Epoch 973/999 | Loss 0.2336 | Win count 219
# Epoch 974/999 | Loss 0.2340 | Win count 219
# Epoch 975/999 | Loss 0.1973 | Win count 219
# Epoch 976/999 | Loss 0.2449 | Win count 220
# Epoch 977/999 | Loss 0.1873 | Win count 220
# Epoch 978/999 | Loss 0.2488 | Win count 220
# Epoch 979/999 | Loss 0.2150 | Win count 220
# Epoch 980/999 | Loss 0.1771 | Win count 220
# Epoch 981/999 | Loss 0.1553 | Win count 220
# Epoch 982/999 | Loss 0.1912 | Win count 220
# Epoch 983/999 | Loss 0.1481 | Win count 220
# Epoch 984/999 | Loss 0.2142 | Win count 220
# Epoch 985/999 | Loss 0.2100 | Win count 221
# Epoch 986/999 | Loss 0.1054 | Win count 221
# Epoch 987/999 | Loss 0.1372 | Win count 222
# Epoch 988/999 | Loss 0.1240 | Win count 222
# Epoch 989/999 | Loss 0.1785 | Win count 223
# Epoch 990/999 | Loss 0.1446 | Win count 223
# Epoch 991/999 | Loss 0.1444 | Win count 224
# Epoch 992/999 | Loss 0.0998 | Win count 225
# Epoch 993/999 | Loss 0.1303 | Win count 225
# Epoch 994/999 | Loss 0.0928 | Win count 226
# Epoch 995/999 | Loss 0.1345 | Win count 226
# Epoch 996/999 | Loss 0.1991 | Win count 226
# Epoch 997/999 | Loss 0.1972 | Win count 226
# Epoch 998/999 | Loss 0.1889 | Win count 226
# Epoch 999/999 | Loss 0.2156 | Win count 226
# wins in last 100: 30
# Epoch 1000/999 | Loss 0.1597 | Win count 226
# Epoch 1001/999 | Loss 0.1778 | Win count 227
# Epoch 1002/999 | Loss 0.1821 | Win count 227
# Epoch 1003/999 | Loss 0.1265 | Win count 227
# Epoch 1004/999 | Loss 0.2373 | Win count 227
# Epoch 1005/999 | Loss 0.2252 | Win count 227
# Epoch 1006/999 | Loss 0.1621 | Win count 227
# Epoch 1007/999 | Loss 0.1623 | Win count 228
# Epoch 1008/999 | Loss 0.2285 | Win count 228
# Epoch 1009/999 | Loss 0.1459 | Win count 228
# Epoch 1010/999 | Loss 0.1311 | Win count 228
# Epoch 1011/999 | Loss 0.1966 | Win count 228
# Epoch 1012/999 | Loss 0.2308 | Win count 228
# Epoch 1013/999 | Loss 0.1059 | Win count 229
# Epoch 1014/999 | Loss 0.1860 | Win count 230
# Epoch 1015/999 | Loss 0.2008 | Win count 231
# Epoch 1016/999 | Loss 0.2444 | Win count 231
# Epoch 1017/999 | Loss 0.3016 | Win count 232
# Epoch 1018/999 | Loss 0.2146 | Win count 233
# Epoch 1019/999 | Loss 0.2913 | Win count 233
# Epoch 1020/999 | Loss 0.2799 | Win count 233
# Epoch 1021/999 | Loss 0.2240 | Win count 233
# Epoch 1022/999 | Loss 0.2027 | Win count 233
# Epoch 1023/999 | Loss 0.2147 | Win count 233
# Epoch 1024/999 | Loss 0.2176 | Win count 233
# Epoch 1025/999 | Loss 0.2203 | Win count 234
# Epoch 1026/999 | Loss 0.2334 | Win count 235
# Epoch 1027/999 | Loss 0.2666 | Win count 235
# Epoch 1028/999 | Loss 0.2315 | Win count 235
# Epoch 1029/999 | Loss 0.2491 | Win count 235
# Epoch 1030/999 | Loss 0.2206 | Win count 235
# Epoch 1031/999 | Loss 0.2877 | Win count 235
# Epoch 1032/999 | Loss 0.2225 | Win count 235
# Epoch 1033/999 | Loss 0.2038 | Win count 236
# Epoch 1034/999 | Loss 0.2539 | Win count 236
# Epoch 1035/999 | Loss 0.2361 | Win count 236
# Epoch 1036/999 | Loss 0.2503 | Win count 236
# Epoch 1037/999 | Loss 0.2271 | Win count 236
# Epoch 1038/999 | Loss 0.2785 | Win count 236
# Epoch 1039/999 | Loss 0.2983 | Win count 237
# Epoch 1040/999 | Loss 0.3419 | Win count 237
# Epoch 1041/999 | Loss 0.2968 | Win count 237
# Epoch 1042/999 | Loss 0.1379 | Win count 238
# Epoch 1043/999 | Loss 0.1937 | Win count 239
# Epoch 1044/999 | Loss 0.3286 | Win count 239
# Epoch 1045/999 | Loss 0.2396 | Win count 240
# Epoch 1046/999 | Loss 0.1894 | Win count 241
# Epoch 1047/999 | Loss 0.2116 | Win count 241
# Epoch 1048/999 | Loss 0.1928 | Win count 241
# Epoch 1049/999 | Loss 0.1487 | Win count 241
# Epoch 1050/999 | Loss 0.1310 | Win count 241
# Epoch 1051/999 | Loss 0.1714 | Win count 241
# Epoch 1052/999 | Loss 0.1390 | Win count 241
# Epoch 1053/999 | Loss 0.1889 | Win count 241
# Epoch 1054/999 | Loss 0.2457 | Win count 241
# Epoch 1055/999 | Loss 0.1378 | Win count 242
# Epoch 1056/999 | Loss 0.1276 | Win count 242
# Epoch 1057/999 | Loss 0.1761 | Win count 243
# Epoch 1058/999 | Loss 0.2280 | Win count 243
# Epoch 1059/999 | Loss 0.2525 | Win count 243
# Epoch 1060/999 | Loss 0.1667 | Win count 243
# Epoch 1061/999 | Loss 0.1851 | Win count 244
# Epoch 1062/999 | Loss 0.1668 | Win count 244
# Epoch 1063/999 | Loss 0.1569 | Win count 245
# Epoch 1064/999 | Loss 0.1466 | Win count 246
# Epoch 1065/999 | Loss 0.1760 | Win count 246
# Epoch 1066/999 | Loss 0.1635 | Win count 247
# Epoch 1067/999 | Loss 0.2028 | Win count 247
# Epoch 1068/999 | Loss 0.1966 | Win count 248
# Epoch 1069/999 | Loss 0.1675 | Win count 248
# Epoch 1070/999 | Loss 0.1507 | Win count 248
# Epoch 1071/999 | Loss 0.1850 | Win count 248
# Epoch 1072/999 | Loss 0.1931 | Win count 248
# Epoch 1073/999 | Loss 0.1938 | Win count 248
# Epoch 1074/999 | Loss 0.1947 | Win count 248
# Epoch 1075/999 | Loss 0.2305 | Win count 248
# Epoch 1076/999 | Loss 0.2028 | Win count 248
# Epoch 1077/999 | Loss 0.1985 | Win count 248
# Epoch 1078/999 | Loss 0.1900 | Win count 248
# Epoch 1079/999 | Loss 0.2224 | Win count 248
# Epoch 1080/999 | Loss 0.2045 | Win count 248
# Epoch 1081/999 | Loss 0.1557 | Win count 248
# Epoch 1082/999 | Loss 0.1549 | Win count 249
# Epoch 1083/999 | Loss 0.1481 | Win count 249
# Epoch 1084/999 | Loss 0.1509 | Win count 249
# Epoch 1085/999 | Loss 0.1560 | Win count 249
# Epoch 1086/999 | Loss 0.1689 | Win count 249
# Epoch 1087/999 | Loss 0.1824 | Win count 249
# Epoch 1088/999 | Loss 0.1421 | Win count 250
# Epoch 1089/999 | Loss 0.1926 | Win count 250
# Epoch 1090/999 | Loss 0.1583 | Win count 250
# Epoch 1091/999 | Loss 0.1785 | Win count 250
# Epoch 1092/999 | Loss 0.1793 | Win count 250
# Epoch 1093/999 | Loss 0.1614 | Win count 251
# Epoch 1094/999 | Loss 0.2031 | Win count 252
# ...
# Epoch 9654/999 | Loss 0.1519 | Win count 2158
# Epoch 9655/999 | Loss 0.1201 | Win count 2159
# Epoch 9656/999 | Loss 0.1392 | Win count 2159
# Epoch 9657/999 | Loss 0.0962 | Win count 2159
# Epoch 9658/999 | Loss 0.1728 | Win count 2159
# Epoch 9659/999 | Loss 0.0842 | Win count 2159
# Epoch 9660/999 | Loss 0.1564 | Win count 2160
# Epoch 9661/999 | Loss 0.1080 | Win count 2161
# Epoch 9662/999 | Loss 0.2048 | Win count 2161
# Epoch 9663/999 | Loss 0.1427 | Win count 2161
# Epoch 9664/999 | Loss 0.1149 | Win count 2162
# Epoch 9665/999 | Loss 0.0663 | Win count 2163
# Epoch 9666/999 | Loss 0.1773 | Win count 2163
# Epoch 9667/999 | Loss 0.1189 | Win count 2163
# Epoch 9668/999 | Loss 0.0976 | Win count 2163
# Epoch 9669/999 | Loss 0.2242 | Win count 2164
# Epoch 9670/999 | Loss 0.2038 | Win count 2164
# Epoch 9671/999 | Loss 0.1279 | Win count 2164
# Epoch 9672/999 | Loss 0.1154 | Win count 2164
# Epoch 9673/999 | Loss 0.1186 | Win count 2164
# Epoch 9674/999 | Loss 0.1941 | Win count 2164
# Epoch 9675/999 | Loss 0.1278 | Win count 2164
# Epoch 9676/999 | Loss 0.0979 | Win count 2165
# Epoch 9677/999 | Loss 0.1358 | Win count 2166
# Epoch 9678/999 | Loss 0.2201 | Win count 2167
# Epoch 9679/999 | Loss 0.1479 | Win count 2168
# Epoch 9680/999 | Loss 0.2237 | Win count 2168
# Epoch 9681/999 | Loss 0.2278 | Win count 2168
# Epoch 9682/999 | Loss 0.1704 | Win count 2169
# Epoch 9683/999 | Loss 0.2108 | Win count 2169
# Epoch 9684/999 | Loss 0.2195 | Win count 2170
# Epoch 9685/999 | Loss 0.2164 | Win count 2170
# Epoch 9686/999 | Loss 0.2206 | Win count 2170
# Epoch 9687/999 | Loss 0.1910 | Win count 2170
# Epoch 9688/999 | Loss 0.1682 | Win count 2170
# Epoch 9689/999 | Loss 0.2394 | Win count 2170
# Epoch 9690/999 | Loss 0.2208 | Win count 2170
# Epoch 9691/999 | Loss 0.2015 | Win count 2170
# Epoch 9692/999 | Loss 0.2624 | Win count 2170
# Epoch 9693/999 | Loss 0.1766 | Win count 2170
# Epoch 9694/999 | Loss 0.1965 | Win count 2170
# Epoch 9695/999 | Loss 0.1883 | Win count 2170
# Epoch 9696/999 | Loss 0.1374 | Win count 2170
# Epoch 9697/999 | Loss 0.2189 | Win count 2170
# Epoch 9698/999 | Loss 0.1577 | Win count 2170
# Epoch 9699/999 | Loss 0.2320 | Win count 2170
# wins in last 100: 28
# Epoch 9700/999 | Loss 0.1658 | Win count 2170
# Epoch 9701/999 | Loss 0.1121 | Win count 2170
# Epoch 9702/999 | Loss 0.1511 | Win count 2170
# Epoch 9703/999 | Loss 0.1488 | Win count 2171
# Epoch 9704/999 | Loss 0.1135 | Win count 2171
# Epoch 9705/999 | Loss 0.1356 | Win count 2171
# Epoch 9706/999 | Loss 0.1575 | Win count 2171
# Epoch 9707/999 | Loss 0.1428 | Win count 2171
# Epoch 9708/999 | Loss 0.0983 | Win count 2171
# Epoch 9709/999 | Loss 0.1526 | Win count 2171
# Epoch 9710/999 | Loss 0.0757 | Win count 2171
# Epoch 9711/999 | Loss 0.0866 | Win count 2171
# Epoch 9712/999 | Loss 0.0806 | Win count 2171
# Epoch 9713/999 | Loss 0.0989 | Win count 2171
# Epoch 9714/999 | Loss 0.0508 | Win count 2171
# Epoch 9715/999 | Loss 0.0738 | Win count 2171
# Epoch 9716/999 | Loss 0.0656 | Win count 2171
# Epoch 9717/999 | Loss 0.0936 | Win count 2171
# Epoch 9718/999 | Loss 0.0426 | Win count 2171
# Epoch 9719/999 | Loss 0.0389 | Win count 2172
# Epoch 9720/999 | Loss 0.0553 | Win count 2172
# Epoch 9721/999 | Loss 0.0467 | Win count 2173
# Epoch 9722/999 | Loss 0.0684 | Win count 2173
# Epoch 9723/999 | Loss 0.0792 | Win count 2173
# Epoch 9724/999 | Loss 0.0450 | Win count 2173
# Epoch 9725/999 | Loss 0.0153 | Win count 2173
# Epoch 9726/999 | Loss 0.0478 | Win count 2174
# Epoch 9727/999 | Loss 0.1137 | Win count 2174
# Epoch 9728/999 | Loss 0.0570 | Win count 2175
# Epoch 9729/999 | Loss 0.0339 | Win count 2175
# Epoch 9730/999 | Loss 0.0434 | Win count 2175
# Epoch 9731/999 | Loss 0.0759 | Win count 2175
# Epoch 9732/999 | Loss 0.0512 | Win count 2176
# Epoch 9733/999 | Loss 0.0546 | Win count 2176
# Epoch 9734/999 | Loss 0.0923 | Win count 2176
# Epoch 9735/999 | Loss 0.0605 | Win count 2176
# Epoch 9736/999 | Loss 0.0414 | Win count 2176
# Epoch 9737/999 | Loss 0.0448 | Win count 2176
# Epoch 9738/999 | Loss 0.0725 | Win count 2176
# Epoch 9739/999 | Loss 0.0733 | Win count 2176
# Epoch 9740/999 | Loss 0.0527 | Win count 2177
# Epoch 9741/999 | Loss 0.0456 | Win count 2178
# Epoch 9742/999 | Loss 0.2040 | Win count 2178
# Epoch 9743/999 | Loss 0.1310 | Win count 2178
# Epoch 9744/999 | Loss 0.0709 | Win count 2179
# Epoch 9745/999 | Loss 0.0754 | Win count 2179
# Epoch 9746/999 | Loss 0.0315 | Win count 2179
# Epoch 9747/999 | Loss 0.0928 | Win count 2180
# Epoch 9748/999 | Loss 0.1105 | Win count 2181
# Epoch 9749/999 | Loss 0.0159 | Win count 2182
# Epoch 9750/999 | Loss 0.1184 | Win count 2182
# Epoch 9751/999 | Loss 0.1259 | Win count 2182
# Epoch 9752/999 | Loss 0.0711 | Win count 2182
# Epoch 9753/999 | Loss 0.1337 | Win count 2182
# Epoch 9754/999 | Loss 0.0698 | Win count 2182
# Epoch 9755/999 | Loss 0.0664 | Win count 2182
# Epoch 9756/999 | Loss 0.0492 | Win count 2182
# Epoch 9757/999 | Loss 0.1756 | Win count 2182
# Epoch 9758/999 | Loss 0.1556 | Win count 2183
# Epoch 9759/999 | Loss 0.1727 | Win count 2183
# Epoch 9760/999 | Loss 0.2154 | Win count 2183
# Epoch 9761/999 | Loss 0.1494 | Win count 2183
# Epoch 9762/999 | Loss 0.1471 | Win count 2184
# Epoch 9763/999 | Loss 0.1409 | Win count 2184
# Epoch 9764/999 | Loss 0.1380 | Win count 2184
# Epoch 9765/999 | Loss 0.2075 | Win count 2184
# Epoch 9766/999 | Loss 0.2091 | Win count 2185
# Epoch 9767/999 | Loss 0.1699 | Win count 2185
# Epoch 9768/999 | Loss 0.1602 | Win count 2185
# Epoch 9769/999 | Loss 0.2078 | Win count 2186
# Epoch 9770/999 | Loss 0.1802 | Win count 2186
# Epoch 9771/999 | Loss 0.2205 | Win count 2186
# Epoch 9772/999 | Loss 0.1999 | Win count 2186
# Epoch 9773/999 | Loss 0.1876 | Win count 2186
# Epoch 9774/999 | Loss 0.2188 | Win count 2186
# Epoch 9775/999 | Loss 0.1784 | Win count 2186
# Epoch 9776/999 | Loss 0.1875 | Win count 2186
# Epoch 9777/999 | Loss 0.1629 | Win count 2186
# Epoch 9778/999 | Loss 0.1584 | Win count 2186
# Epoch 9779/999 | Loss 0.1261 | Win count 2186
# Epoch 9780/999 | Loss 0.1318 | Win count 2186
# Epoch 9781/999 | Loss 0.1535 | Win count 2186
# Epoch 9782/999 | Loss 0.1665 | Win count 2186
# Epoch 9783/999 | Loss 0.1957 | Win count 2186
# Epoch 9784/999 | Loss 0.0384 | Win count 2187
# Epoch 9785/999 | Loss 0.0995 | Win count 2188
# Epoch 9786/999 | Loss 0.1462 | Win count 2189
# Epoch 9787/999 | Loss 0.1496 | Win count 2190
# Epoch 9788/999 | Loss 0.1165 | Win count 2190
# Epoch 9789/999 | Loss 0.1551 | Win count 2190
# Epoch 9790/999 | Loss 0.1443 | Win count 2190
# Epoch 9791/999 | Loss 0.1051 | Win count 2190
# Epoch 9792/999 | Loss 0.0811 | Win count 2190
# Epoch 9793/999 | Loss 0.1678 | Win count 2190
# Epoch 9794/999 | Loss 0.1690 | Win count 2191
# Epoch 9795/999 | Loss 0.1189 | Win count 2192
# Epoch 9796/999 | Loss 0.1029 | Win count 2192
# Epoch 9797/999 | Loss 0.1017 | Win count 2192
# Epoch 9798/999 | Loss 0.1781 | Win count 2192
# Epoch 9799/999 | Loss 0.2054 | Win count 2192
# wins in last 100: 23
# Epoch 9800/999 | Loss 0.1516 | Win count 2193
# Epoch 9801/999 | Loss 0.1567 | Win count 2193
# Epoch 9802/999 | Loss 0.1082 | Win count 2193
# Epoch 9803/999 | Loss 0.1349 | Win count 2194
# Epoch 9804/999 | Loss 0.1402 | Win count 2194
# Epoch 9805/999 | Loss 0.1670 | Win count 2194
# Epoch 9806/999 | Loss 0.1906 | Win count 2194
# Epoch 9807/999 | Loss 0.1935 | Win count 2194
# Epoch 9808/999 | Loss 0.2369 | Win count 2195
# Epoch 9809/999 | Loss 0.2179 | Win count 2195
# Epoch 9810/999 | Loss 0.1589 | Win count 2195
# Epoch 9811/999 | Loss 0.2686 | Win count 2195
# Epoch 9812/999 | Loss 0.2406 | Win count 2195
# Epoch 9813/999 | Loss 0.1675 | Win count 2196
# Epoch 9814/999 | Loss 0.1641 | Win count 2197
# Epoch 9815/999 | Loss 0.2238 | Win count 2197
# Epoch 9816/999 | Loss 0.1669 | Win count 2197
# Epoch 9817/999 | Loss 0.1719 | Win count 2197
# Epoch 9818/999 | Loss 0.1823 | Win count 2197
# Epoch 9819/999 | Loss 0.1130 | Win count 2197
# Epoch 9820/999 | Loss 0.2245 | Win count 2198
# Epoch 9821/999 | Loss 0.1254 | Win count 2199
# Epoch 9822/999 | Loss 0.2086 | Win count 2200
# Epoch 9823/999 | Loss 0.1633 | Win count 2201
# Epoch 9824/999 | Loss 0.1792 | Win count 2201
# Epoch 9825/999 | Loss 0.1311 | Win count 2201
# Epoch 9826/999 | Loss 0.1442 | Win count 2201
# Epoch 9827/999 | Loss 0.1708 | Win count 2201
# Epoch 9828/999 | Loss 0.1403 | Win count 2202
# Epoch 9829/999 | Loss 0.1253 | Win count 2202
# Epoch 9830/999 | Loss 0.1514 | Win count 2203
# Epoch 9831/999 | Loss 0.1400 | Win count 2203
# Epoch 9832/999 | Loss 0.1313 | Win count 2203
# Epoch 9833/999 | Loss 0.1277 | Win count 2203
# Epoch 9834/999 | Loss 0.1188 | Win count 2203
# Epoch 9835/999 | Loss 0.1590 | Win count 2203
# Epoch 9836/999 | Loss 0.1451 | Win count 2204
# Epoch 9837/999 | Loss 0.1295 | Win count 2205
# Epoch 9838/999 | Loss 0.1244 | Win count 2206
# Epoch 9839/999 | Loss 0.1504 | Win count 2207
# Epoch 9840/999 | Loss 0.2207 | Win count 2207
# Epoch 9841/999 | Loss 0.1138 | Win count 2207
# Epoch 9842/999 | Loss 0.1139 | Win count 2207
# Epoch 9843/999 | Loss 0.1883 | Win count 2207
# Epoch 9844/999 | Loss 0.1096 | Win count 2207
# Epoch 9845/999 | Loss 0.1475 | Win count 2207
# Epoch 9846/999 | Loss 0.1450 | Win count 2208
# Epoch 9847/999 | Loss 0.0912 | Win count 2208
# Epoch 9848/999 | Loss 0.1973 | Win count 2208
# Epoch 9849/999 | Loss 0.1284 | Win count 2208
# Epoch 9850/999 | Loss 0.1474 | Win count 2209
# Epoch 9851/999 | Loss 0.1094 | Win count 2210
# Epoch 9852/999 | Loss 0.1003 | Win count 2210
# Epoch 9853/999 | Loss 0.1189 | Win count 2210
# Epoch 9854/999 | Loss 0.1241 | Win count 2210
# Epoch 9855/999 | Loss 0.1150 | Win count 2210
# Epoch 9856/999 | Loss 0.1230 | Win count 2211
# Epoch 9857/999 | Loss 0.1212 | Win count 2211
# Epoch 9858/999 | Loss 0.0705 | Win count 2211
# Epoch 9859/999 | Loss 0.1171 | Win count 2211
# Epoch 9860/999 | Loss 0.1886 | Win count 2211
# Epoch 9861/999 | Loss 0.1191 | Win count 2211
# Epoch 9862/999 | Loss 0.1089 | Win count 2212
# Epoch 9863/999 | Loss 0.1050 | Win count 2212
# Epoch 9864/999 | Loss 0.1715 | Win count 2212
# Epoch 9865/999 | Loss 0.1600 | Win count 2213
# Epoch 9866/999 | Loss 0.1974 | Win count 2213
# Epoch 9867/999 | Loss 0.1228 | Win count 2213
# Epoch 9868/999 | Loss 0.1655 | Win count 2213
# Epoch 9869/999 | Loss 0.1269 | Win count 2213
# Epoch 9870/999 | Loss 0.1452 | Win count 2213
# Epoch 9871/999 | Loss 0.1364 | Win count 2213
# Epoch 9872/999 | Loss 0.2150 | Win count 2213
# Epoch 9873/999 | Loss 0.1453 | Win count 2213
# Epoch 9874/999 | Loss 0.1275 | Win count 2213
# Epoch 9875/999 | Loss 0.0889 | Win count 2213
# Epoch 9876/999 | Loss 0.0765 | Win count 2214
# Epoch 9877/999 | Loss 0.1278 | Win count 2214
# Epoch 9878/999 | Loss 0.0934 | Win count 2214
# Epoch 9879/999 | Loss 0.1117 | Win count 2214
# Epoch 9880/999 | Loss 0.1566 | Win count 2214
# Epoch 9881/999 | Loss 0.1485 | Win count 2214
# Epoch 9882/999 | Loss 0.1176 | Win count 2214
# Epoch 9883/999 | Loss 0.1425 | Win count 2214
# Epoch 9884/999 | Loss 0.1160 | Win count 2214
# Epoch 9885/999 | Loss 0.1421 | Win count 2214
# Epoch 9886/999 | Loss 0.0916 | Win count 2214
# Epoch 9887/999 | Loss 0.1119 | Win count 2214
# Epoch 9888/999 | Loss 0.0908 | Win count 2215
# Epoch 9889/999 | Loss 0.1172 | Win count 2215
# Epoch 9890/999 | Loss 0.0997 | Win count 2215
# Epoch 9891/999 | Loss 0.0965 | Win count 2215
# Epoch 9892/999 | Loss 0.0716 | Win count 2215
# Epoch 9893/999 | Loss 0.0852 | Win count 2215
# Epoch 9894/999 | Loss 0.0857 | Win count 2215
# Epoch 9895/999 | Loss 0.0606 | Win count 2215
# Epoch 9896/999 | Loss 0.1018 | Win count 2215
# Epoch 9897/999 | Loss 0.0865 | Win count 2215
# Epoch 9898/999 | Loss 0.0732 | Win count 2215
# Epoch 9899/999 | Loss 0.0626 | Win count 2215
# wins in last 100: 23
# Epoch 9900/999 | Loss 0.0405 | Win count 2216
# Epoch 9901/999 | Loss 0.0345 | Win count 2216
# Epoch 9902/999 | Loss 0.0234 | Win count 2217
# Epoch 9903/999 | Loss 0.0256 | Win count 2217
# Epoch 9904/999 | Loss 0.0226 | Win count 2217
# Epoch 9905/999 | Loss 0.1181 | Win count 2217
# Epoch 9906/999 | Loss 0.0154 | Win count 2217
# Epoch 9907/999 | Loss 0.0385 | Win count 2217
# Epoch 9908/999 | Loss 0.0602 | Win count 2217
# Epoch 9909/999 | Loss 0.0354 | Win count 2217
# Epoch 9910/999 | Loss 0.0656 | Win count 2218
# Epoch 9911/999 | Loss 0.1011 | Win count 2218
# Epoch 9912/999 | Loss 0.0353 | Win count 2219
# Epoch 9913/999 | Loss 0.0554 | Win count 2219
# Epoch 9914/999 | Loss 0.0863 | Win count 2219
# Epoch 9915/999 | Loss 0.0804 | Win count 2219
# Epoch 9916/999 | Loss 0.0917 | Win count 2219
# Epoch 9917/999 | Loss 0.1032 | Win count 2220
# Epoch 9918/999 | Loss 0.0977 | Win count 2220
# Epoch 9919/999 | Loss 0.1246 | Win count 2221
# Epoch 9920/999 | Loss 0.0927 | Win count 2221
# Epoch 9921/999 | Loss 0.2020 | Win count 2221
# Epoch 9922/999 | Loss 0.1580 | Win count 2222
# Epoch 9923/999 | Loss 0.1064 | Win count 2222
# Epoch 9924/999 | Loss 0.0965 | Win count 2222
# Epoch 9925/999 | Loss 0.1637 | Win count 2222
# Epoch 9926/999 | Loss 0.1310 | Win count 2222
# Epoch 9927/999 | Loss 0.1398 | Win count 2222
# Epoch 9928/999 | Loss 0.1856 | Win count 2223
# Epoch 9929/999 | Loss 0.1221 | Win count 2223
# Epoch 9930/999 | Loss 0.2455 | Win count 2223
# Epoch 9931/999 | Loss 0.1434 | Win count 2223
# Epoch 9932/999 | Loss 0.1491 | Win count 2224
# Epoch 9933/999 | Loss 0.2279 | Win count 2224
# Epoch 9934/999 | Loss 0.0783 | Win count 2224
# Epoch 9935/999 | Loss 0.2014 | Win count 2225
# Epoch 9936/999 | Loss 0.1778 | Win count 2225
# Epoch 9937/999 | Loss 0.0990 | Win count 2225
# Epoch 9938/999 | Loss 0.2569 | Win count 2225
# Epoch 9939/999 | Loss 0.1481 | Win count 2225
# Epoch 9940/999 | Loss 0.1440 | Win count 2225
# Epoch 9941/999 | Loss 0.1598 | Win count 2225
# Epoch 9942/999 | Loss 0.1567 | Win count 2226
# Epoch 9943/999 | Loss 0.1689 | Win count 2227
# Epoch 9944/999 | Loss 0.1399 | Win count 2227
# Epoch 9945/999 | Loss 0.1441 | Win count 2227
# Epoch 9946/999 | Loss 0.1127 | Win count 2228
# Epoch 9947/999 | Loss 0.2149 | Win count 2228
# Epoch 9948/999 | Loss 0.1623 | Win count 2228
# Epoch 9949/999 | Loss 0.2523 | Win count 2228
# Epoch 9950/999 | Loss 0.1691 | Win count 2228
# Epoch 9951/999 | Loss 0.1612 | Win count 2228
# Epoch 9952/999 | Loss 0.1525 | Win count 2228
# Epoch 9953/999 | Loss 0.1703 | Win count 2228
# Epoch 9954/999 | Loss 0.1293 | Win count 2228
# Epoch 9955/999 | Loss 0.2298 | Win count 2228
# Epoch 9956/999 | Loss 0.1996 | Win count 2228
# Epoch 9957/999 | Loss 0.2345 | Win count 2228
# Epoch 9958/999 | Loss 0.1891 | Win count 2228
# Epoch 9959/999 | Loss 0.1566 | Win count 2228
# Epoch 9960/999 | Loss 0.1775 | Win count 2228
# Epoch 9961/999 | Loss 0.1664 | Win count 2228
# Epoch 9962/999 | Loss 0.1429 | Win count 2228
# Epoch 9963/999 | Loss 0.1502 | Win count 2228
# Epoch 9964/999 | Loss 0.1605 | Win count 2228
# Epoch 9965/999 | Loss 0.1057 | Win count 2229
# Epoch 9966/999 | Loss 0.1333 | Win count 2229
# Epoch 9967/999 | Loss 0.1286 | Win count 2229
# Epoch 9968/999 | Loss 0.1188 | Win count 2229
# Epoch 9969/999 | Loss 0.1194 | Win count 2229
# Epoch 9970/999 | Loss 0.1297 | Win count 2229
# Epoch 9971/999 | Loss 0.1377 | Win count 2229
# Epoch 9972/999 | Loss 0.1985 | Win count 2230
# Epoch 9973/999 | Loss 0.0952 | Win count 2230
# Epoch 9974/999 | Loss 0.0681 | Win count 2230
# Epoch 9975/999 | Loss 0.0994 | Win count 2231
# Epoch 9976/999 | Loss 0.1031 | Win count 2231
# Epoch 9977/999 | Loss 0.0687 | Win count 2232
# Epoch 9978/999 | Loss 0.0727 | Win count 2233
# Epoch 9979/999 | Loss 0.1200 | Win count 2233
# Epoch 9980/999 | Loss 0.0907 | Win count 2233
# Epoch 9981/999 | Loss 0.1871 | Win count 2233
# Epoch 9982/999 | Loss 0.0563 | Win count 2233
# Epoch 9983/999 | Loss 0.0655 | Win count 2233
# Epoch 9984/999 | Loss 0.0843 | Win count 2233
# Epoch 9985/999 | Loss 0.0747 | Win count 2233
# Epoch 9986/999 | Loss 0.0600 | Win count 2233
# Epoch 9987/999 | Loss 0.0676 | Win count 2233
# Epoch 9988/999 | Loss 0.0550 | Win count 2233
# Epoch 9989/999 | Loss 0.0623 | Win count 2233
# Epoch 9990/999 | Loss 0.0531 | Win count 2233
# Epoch 9991/999 | Loss 0.0749 | Win count 2233
# Epoch 9992/999 | Loss 0.0570 | Win count 2233
# Epoch 9993/999 | Loss 0.0398 | Win count 2233
# Epoch 9994/999 | Loss 0.0506 | Win count 2233
# Epoch 9995/999 | Loss 0.0379 | Win count 2234
# Epoch 9996/999 | Loss 0.0372 | Win count 2234
# Epoch 9997/999 | Loss 0.0602 | Win count 2234
# Epoch 9998/999 | Loss 0.0367 | Win count 2234
# Epoch 9999/999 | Loss 0.0268 | Win count 2234

# %%
##
class Catch(object):
    def __init__(self, grid_size=10):
        self.grid_size = grid_size
        self.reset()

    def _update_state(self, action):
        """
        Input: action and states
        Ouput: new states and reward
        """
        state = self.state
        if action == 0:  # left
            action = -1
        elif action == 1:  # stay
            action = 0
        else:
            action = 1  # right
        f0, f1, basket = state[0]
        new_basket = min(max(1, basket + action), self.grid_size-1)
        f0 += 1
        out = np.asarray([f0, f1, new_basket])
        out = out[np.newaxis]

        assert len(out.shape) == 2
        self.state = out

    def _draw_state(self):
        im_size = (self.grid_size,)*2
        state = self.state[0]
        canvas = np.zeros(im_size)
        canvas[state[0], state[1]] = 1  # draw fruit
        canvas[-1, state[2]-1:state[2] + 2] = 1  # draw basket
        return canvas

    def _get_reward(self):
        fruit_row, fruit_col, basket = self.state[0]
        if fruit_row == self.grid_size-1:
            if abs(fruit_col - basket) <= 1:
                return 1
            else:
                return -1
        else:
            return 0

    def _is_over(self):
        if self.state[0, 0] == self.grid_size-1:
            return True
        else:
            return False

    def observe(self):
        canvas = self._draw_state()
        # return canvas.reshape((1, -1))
        return canvas.reshape(1, canvas.shape[0], canvas.shape[0], 1)

    def act(self, action):
        self._update_state(action)
        reward = self._get_reward()
        game_over = self._is_over()
        return self.observe(), reward, game_over

    def reset(self):
        n = np.random.randint(0, self.grid_size-1, size=1)
        m = np.random.randint(1, self.grid_size-2, size=1)
        self.state = np.asarray([0, n, m])[np.newaxis]


class ExperienceReplay(object):
    def __init__(self, max_memory=100, discount=.9):
        self.max_memory = max_memory
        self.memory = list()
        self.discount = discount

    def remember(self, states, game_over):
        # memory[i] = [[state_t, action_t, reward_t, state_t+1], game_over?]
        self.memory.append([states, game_over])
        if len(self.memory) > self.max_memory:
            del self.memory[0]

    def get_batch(self, model, batch_size=10):
        len_memory = len(self.memory)
        num_actions = model.output_shape[-1]
        env_dim = self.memory[0][0][0].shape[1]
        # inputs = np.zeros((min(len_memory, batch_size), env_dim))

        inputs = np.zeros((min(len_memory, batch_size), env_dim, env_dim, 1))
#         print(inputs.shape)
        
        targets = np.zeros((inputs.shape[0], num_actions))
        for i, idx in enumerate(np.random.randint(0, len_memory,
                                                  size=inputs.shape[0])):
            state_t, action_t, reward_t, state_tp1 = self.memory[idx][0]
            game_over = self.memory[idx][1]

            inputs[i:i+1] = state_t
            # There should be no target values for actions not taken.
            # Thou shalt not correct actions not taken #deep
            targets[i] = model.predict(state_t)[0]
            Q_sa = np.max(model.predict(state_tp1)[0])
            if game_over:  # if game_over is True
                targets[i, action_t] = reward_t
            else:
                # reward_t + gamma * max_a' Q(s', a')
                targets[i, action_t] = reward_t + self.discount * Q_sa
#         print(inputs[0])
        return inputs, targets


# if __name__ == "__main__":

#
def train(model):
    win_cnt = 0
    last_cnt = 0
    for e in range(epoch):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        input_t = env.observe()

        while not game_over:
            input_tm1 = input_t
            # get next action
            if np.random.rand() <= epsilon:
                action = np.random.randint(0, num_actions, size=1)
            else:
                q = model.predict(input_tm1)
                action = np.argmax(q[0])

            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)
            if reward == 1:
                win_cnt += 1

            # store experience
            exp_replay.remember([input_tm1, action, reward, input_t], game_over)

            # adapt model
            inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)

            loss += model.train_on_batch(inputs, targets)
        if e % 100 == 0:
            in_last = win_cnt - last_cnt
            print("wins in last 100:",in_last)
            last_cnt = win_cnt
        print("Epoch {:03d}/999 | Loss {:.4f} | Win count {}".format(e, loss, win_cnt))

    # Save trained model weights and architecture, this will be used by the visualization code
    model.save_weights("model.h5", overwrite=True)
    with open("model.json", "w") as outfile:
        json.dump(model.to_json(), outfile)
